# %%
import pandas as pd

# %%
file = '/data/users/hgilmour/initial_tracks/tobac_initial_tracks/tracking/tracks_1998.h5'

# %%
tracks_1998 = pd.read_hdf(file, 'table')

# %%
tracks_1998
# Out:
#       frame  idx       hdim_1       hdim_2    num  threshold_value  feature  \
# 0         0    2    57.815963   464.806452   4557              240        1
# 1         0    4   110.665812   342.682587   8543              240        2
# 2         0   12   180.448793   779.083627   6009              240        3
# 3         0   16   292.415458   877.117843   8054              240        4
# 4         0   17   310.445716   723.260186   2701              240        5
# ...     ...  ...          ...          ...    ...              ...      ...
# 7656    743   74  1020.663052   529.391628   2374              240     7657
# 7657    743  105  1215.852215   104.249528  37521              240     7658
# 7658    743  112  1158.980466  1088.906848  13270              240     7659
# 7659    743  118  1212.979859   695.678771  65346              240     7660
# 7660    743  176  1247.231526   257.024840   2956              240     7661
#
# ...

# %%
# Sort dataframe into date order by first converting timestr to datetime
tracks_1998["timestr"] = tracks_1998["timestr"].astype('datetime64[ns]')

# Sort DataFrame by date column
tracks_1998.sort_values(by='timestr', inplace = True)

# %%
tracks_1998
# Out:
#       frame  idx       hdim_1       hdim_2    num  threshold_value  feature  \
# 8         0  168   989.100753  1310.650767   9310              240        9
# 0         0    2   106.094677   542.929600  31239              240        1
# 1         0    8   434.854273   747.635519  28419              240        2
# 2         0   20   533.697618   937.641720  10675              240        3
# 3         0   73   723.607307   647.238123  15813              240        4
# ...     ...  ...          ...          ...    ...              ...      ...
# 8775    743    7   310.961207   517.844138  17044              240     8776
# 8774    743    1   229.376237   725.723547  12081              240     8775
# 8788    743  348  1172.700632   208.199459   2012              240     8789
# 8780    743  179   736.655974   219.846178   2448              240     8781
# 8787    743  281  1014.425553   418.327558   5939              240     8788
#
# ...
